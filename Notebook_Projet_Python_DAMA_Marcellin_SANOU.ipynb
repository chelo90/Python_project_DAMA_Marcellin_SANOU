# %% [markdown]
# ## Intitulé du projet : Analyse des données de santé « Cas du Paludisme en Afrique »

# %% [markdown]
# ### Contenu du Dataset « Africa Malaria » :
# L'ensemble de données "Africa Malaria" comprend des données sur les pays africains de 2007 à 2017, avec les caractéristiques suivantes :
# - Code de pays ISO-3 unique : Chaque pays est identifié par un code de pays ISO-3, qui est un code standardisé utilisé pour représenter les pays dans les données internationales.
# - Latitude et longitude : Pour chaque pays, l'ensemble de données fournit également les coordonnées de latitude et de longitude, qui donnent la position géographique approximative du pays.
# - Cas de paludisme signalés : L'ensemble de données comprend des informations sur les cas de paludisme signalés dans chaque pays et chaque année. Ces données peuvent inclure le nombre total de cas, le nombre de cas selon le sexe, l'âge ou d'autres caractéristiques démographiques, ainsi que la gravité des cas signalés.
# - Mesures préventives : L'ensemble de données fournit également des données sur les mesures préventives prises pour lutter contre le paludisme dans chaque pays. Cela peut inclure des informations sur les campagnes de sensibilisation, les programmes de distribution de moustiquaires, les traitements médicaux administrés, etc.

# %% [markdown]
# ### 1. Importation des bibliothèques pandas, numpy et matplotlib, pour manipuler les données et effectuer des analyses statistiques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Chargement du fichier du Dataset dans un dataframe pandas
# Lien de téléchargement du Dataset : https://www.kaggle.com/datasets/lydia70/malaria-in-africa

# %%
df = pd.read_csv("DatasetAfricaMalaria.csv")

# %% [markdown]
# ### 3. Nettoyage et structuration des données pour l'analyse

# %% [markdown]
# #### 3.1. Copie du Dataset

# %%
dfc = df.copy()

# %% [markdown]
# #### 3.2. Affichage des 5 premières lignes du Dataset

# %%
dfc.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 0                                                NaN
# 1                                               29.8
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 0                                                NaN
# 1                                                1.5
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    People using safely managed drinking water services (% of population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    People using safely managed drinking water services, rural (% of rural population)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  Urban population growth (annual %)  \
# 0  ...                                2.71
# 1  ...                                5.01
# 2  ...                                4.09
# 3  ...                                4.80
# 4  ...                                5.91
#
#    People using at least basic drinking water services (% of population)  \
# 0                                              91.68
# 1                                              47.96
# 2                                              63.78
# 3                                              78.89
# 4                                              52.27
#
#    People using at least basic drinking water services, rural (% of rural population)  \
# 0                                              85.83
# 1                                              23.77
# 2                                              54.92
# 3                                              57.60
# 4                                              45.13
#
#    People using at least basic drinking water services, urban (% of urban population)  \
# 0                                              94.78
# 1                                              65.83
# 2                                              76.24
# 3                                              94.35
# 4                                              76.15
#
#    People using at least basic sanitation services (% of population)  \
# 0                                              85.85
# 1                                              37.26
# 2                                              11.80
# 3                                              61.60
# 4                                              15.60
#
#    People using at least basic sanitation services, rural (% of rural population)  \
# 0                                              76.94
# 1                                              14.00
# 2                                               4.29
# 3                                              39.99
# 4                                               6.38
#
#    People using at least basic sanitation services, urban  (% of urban population)  \
# 0                                              90.57
# 1                                              54.44
# 2                                              22.36
# 3                                              77.30
# 4                                              46.49
#
#     latitude  longitude                            geometry
# 0  28.033886   1.659626          POINT (28.033886 1.659626)
# 1 -11.202692  17.873887        POINT (-11.202692 17.873887)
# 2   9.307690   2.315834  POINT (9.307689999999999 2.315834)
# 3 -22.328474  24.684866        POINT (-22.328474 24.684866)
# 4  12.238333  -1.561593         POINT (12.238333 -1.561593)
#
# [5 rows x 27 columns]

# %% [markdown]
# #### 3.3. Affichage des 5 dernières lignes du Dataset

# %%
dfc.tail()
# Out:
#     Country Name  Year Country Code  \
# 589         Togo  2017          TGO
# 590      Tunisia  2017          TUN
# 591       Uganda  2017          UGA
# 592       Zambia  2017          ZMB
# 593     Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 589                                             278.20
# 590                                                NaN
# 591                                             336.76
# 592                                             160.05
# 593                                             108.55
#
#      Malaria cases reported  \
# 589               1755577.0
# 590                     NaN
# 591              11667831.0
# 592               5505639.0
# 593                467508.0
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 589                                               69.7
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 589                                               31.1
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 589                                               41.7
# 590                                                NaN
# 591                                                NaN
# 592                                                NaN
# 593                                                NaN
#
#      People using safely managed drinking water services (% of population)  \
# 589                                                NaN
# 590                                              92.66
# 591                                               7.07
# 592                                                NaN
# 593                                                NaN
#
#      People using safely managed drinking water services, rural (% of rural population)  \
# 589                                                NaN
# 590                                                NaN
# 591                                               4.46
# 592                                                NaN
# 593                                                NaN
#
#      ...  Urban population growth (annual %)  \
# 589  ...                                3.79
# 590  ...                                1.57
# 591  ...                                6.25
# 592  ...                                4.21
# 593  ...                                1.28
#
#      People using at least basic drinking water services (% of population)  \
# 589                                              65.13
# 590                                              96.25
# 591                                              49.10
# 592                                              59.96
# 593                                              64.05
#
#      People using at least basic drinking water services, rural (% of rural population)  \
# 589                                              48.39
# 590                                              88.71
# 591                                              41.25
# 592                                              41.95
# 593                                              49.80
#
#      People using at least basic drinking water services, urban (% of urban population)  \
# 589                                              89.06
# 590                                              99.70
# 591                                              75.11
# 592                                              83.86
# 593                                              94.00
#
#      People using at least basic sanitation services (% of population)  \
# 589                                              16.13
# 590                                              90.92
# 591                                              18.47
# 592                                              26.37
# 593                                              36.22
#
#      People using at least basic sanitation services, rural (% of rural population)  \
# 589                                               7.40
# 590                                              81.35
# 591                                              16.17
# 592                                              18.93
# 593                                              31.47
#
#      People using at least basic sanitation services, urban  (% of urban population)  \
# 589                                              28.61
# 590                                              95.29
# 591                                              26.11
# 592                                              36.24
# 593                                              46.22
#
#       latitude  longitude                      geometry
# 589   8.619543   0.824782     POINT (8.619543 0.824782)
# 590  33.886917   9.537499    POINT (33.886917 9.537499)
# 591   1.373333  32.290275    POINT (1.373333 32.290275)
# 592 -13.133897  27.849332  POINT (-13.133897 27.849332)
# 593 -19.015438  29.154857  POINT (-19.015438 29.154857)
#
# [5 rows x 27 columns]

# %% [markdown]
# #### 3.4. Examen des différentes colonnes et types de données dans le Dataset

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Country Name                                                                             594 non-null    object
#  1   Year                                                                                     594 non-null    int64
#  2   Country Code                                                                             594 non-null    object
#  3   Incidence of malaria (per 1,000 population at risk)                                      550 non-null    float64
#  4   Malaria cases reported                                                                   550 non-null    float64
#  5   Use of insecticide-treated bed nets (% of under-5 population)                            132 non-null    float64
#  6   Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  122 non-null    float64
#  7   Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)    106 non-null    float64
#  8   People using safely managed drinking water services (% of population)                    99 non-null     float64
#  9   People using safely managed drinking water services, rural (% of rural population)       88 non-null     float64
#  10  People using safely managed drinking water services, urban (% of urban population)       176 non-null    float64
#  11  People using safely managed sanitation services (% of population)                        132 non-null    float64
#  12  People using safely managed sanitation services, rural (% of rural population)           110 non-null    float64
#  13  People using safely managed sanitation services, urban  (% of urban population)          132 non-null    float64
#  14  Rural population (% of total population)                                                 588 non-null    float64
#  15  Rural population growth (annual %)                                                       588 non-null    float64
#  16  Urban population (% of total population)                                                 588 non-null    float64
#  17  Urban population growth (annual %)                                                       588 non-null    float64
#  18  People using at least basic drinking water services (% of population)                    588 non-null    float64
#  19  People using at least basic drinking water services, rural (% of rural population)       566 non-null    float64
#  20  People using at least basic drinking water services, urban (% of urban population)       566 non-null    float64
#  21  People using at least basic sanitation services (% of population)                        588 non-null    float64
#  22  People using at least basic sanitation services, rural (% of rural population)           566 non-null    float64
#  23  People using at least basic sanitation services, urban  (% of urban population)          566 non-null    float64
#  24  latitude                                                                                 594 non-null    float64
#  25  longitude                                                                                594 non-null    float64
#  26  geometry                                                                                 594 non-null    object
# dtypes: float64(23), int64(1), object(3)
# memory usage: 125.4+ KB

# %% [markdown]
# ##### Nombre d'index dans notre Dataset

# %%
dfc.index
# Out:
# RangeIndex(start=0, stop=594, step=1)

# %% [markdown]
# ##### Conversion du type de données de la colonne "Malaria cases reported" en nombre entier

# %%
dfc['Malaria cases reported']
# Out:
# 0            26.0
# 1       1533485.0
# 2             0.0
# 3           390.0
# 4         44246.0
#           ...
# 589     1755577.0
# 590           NaN
# 591    11667831.0
# 592     5505639.0
# 593      467508.0
# Name: Malaria cases reported, Length: 594, dtype: float64

# %%
dfc['Malaria cases reported'] = dfc['Malaria cases reported'].astype('Int64')

# %%
dfc['Malaria cases reported']
# Out:
# 0            26
# 1       1533485
# 2             0
# 3           390
# 4         44246
#          ...
# 589     1755577
# 590        <NA>
# 591    11667831
# 592     5505639
# 593      467508
# Name: Malaria cases reported, Length: 594, dtype: Int64

# %% [markdown]
# ##### Renommons certaines colonnes de notre Dataset

# %%
### Listons les noms de colonnes du Dataset avant renommage
list(dfc)
# Out:
# ['Country Name',
#  'Year',
#  'Country Code',
#  'Incidence of malaria (per 1,000 population at risk)',
#  'Malaria cases reported',
#  'Use of insecticide-treated bed nets (% of under-5 population)',
#  'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#  'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#  'People using safely managed drinking water services (% of population)',
#  'People using safely managed drinking water services, rural (% of rural population)',
#  'People using safely managed drinking water services, urban (% of urban population)',
#  'People using safely managed sanitation services (% of population)',
#  'People using safely managed sanitation services, rural (% of rural population)',
#  'People using safely managed sanitation services, urban  (% of urban population)',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Urban population (% of total population)',
#  'Urban population growth (annual %)',
#  'People using at least basic drinking water services (% of population)',
#  'People using at least basic drinking water services, rural (% of rural population)',
#  'People using at least basic drinking water services, urban (% of urban population)',
#  'People using at least basic sanitation services (% of population)',
#  'People using at least basic sanitation services, rural (% of rural population)',
#  'People using at least basic sanitation services, urban  (% of urban population)',
#  'latitude',
#  'longitude',
#  'geometry']

# %% [markdown]
# #### Renommage des colonnes du Dataset

# %%
dfc.rename(columns = {'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)':'% of children under age 5 with fever receiving antimalarial drugs', 'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)':'% of pregnant women using Intermittent preventive treatment (IPT) of malaria in pregnancy', 'People using safely managed drinking water services (% of population)':'% of population using safely managed drinking water services', 'People using safely managed drinking water services, rural (% of rural population)':'% of rural population using safely managed drinking water services', 'People using safely managed drinking water services, urban (% of urban population)':'% of urban population using safely managed drinking water services', 'People using safely managed sanitation services (% of population)':'% of population using safely managed sanitation services', 'People using safely managed sanitation services, rural (% of rural population)':'% of rural population using safely managed sanitation services', 'People using safely managed sanitation services, urban  (% of urban population)':'% of urban population using safely managed sanitation services', 'People using at least basic drinking water services (% of population)':'% of population using at least basic drinking water services', 'People using at least basic drinking water services, rural (% of rural population)':'% of rural population using at least basic drinking water services', 'People using at least basic drinking water services, urban (% of urban population)':'% of urban population using at least basic drinking water services', 'People using at least basic sanitation services (% of population)':' % of population using at least basic sanitation services', 'People using at least basic sanitation services, rural (% of rural population)':'% of rural population using at least basic sanitation services', 'People using at least basic sanitation services, urban  (% of urban population)':'% of urban population using at least basic sanitation services', 'geometry':'Localisation'}, inplace = True)

# %%
list(dfc)
# Out:
# ['Country Name',
#  'Year',
#  'Country Code',
#  'Incidence of malaria (per 1,000 population at risk)',
#  'Malaria cases reported',
#  'Use of insecticide-treated bed nets (% of under-5 population)',
#  '% of children under age 5 with fever receiving antimalarial drugs',
#  '% of pregnant women using Intermittent preventive treatment (IPT) of malaria in pregnancy',
#  '% of population using safely managed drinking water services',
#  '% of rural population using safely managed drinking water services',
#  '% of urban population using safely managed drinking water services',
#  '% of population using safely managed sanitation services',
#  '% of rural population using safely managed sanitation services',
#  '% of urban population using safely managed sanitation services',
#  'Rural population (% of total population)',
#  'Rural population growth (annual %)',
#  'Urban population (% of total population)',
#  'Urban population growth (annual %)',
#  '% of population using at least basic drinking water services',
#  '% of rural population using at least basic drinking water services',
#  '% of urban population using at least basic drinking water services',
#  ' % of population using at least basic sanitation services',
#  '% of rural population using at least basic sanitation services',
#  '% of urban population using at least basic sanitation services',
#  'latitude',
#  'longitude',
#  'Localisation']

# %% [markdown]
# ### 4. Analyse exploratoire des données

# %% [markdown]
# ####  4.1. Statistiques descriptives du Dataset

# %%
df.describe()
# Out:
#               Year  Incidence of malaria (per 1,000 population at risk)  \
# count   594.000000                                         550.000000
# mean   2012.000000                                         190.087491
# std       3.164943                                         163.054527
# min    2007.000000                                           0.000000
# 25%    2009.000000                                          30.857500
# 50%    2012.000000                                         174.775000
# 75%    2015.000000                                         347.637500
# max    2017.000000                                         585.540000
#
#        Malaria cases reported  \
# count            5.500000e+02
# mean             1.068330e+06
# std              2.192802e+06
# min              0.000000e+00
# 25%              2.211750e+03
# 50%              1.130260e+05
# 75%              1.154808e+06
# max              1.682113e+07
#
#        Use of insecticide-treated bed nets (% of under-5 population)  \
# count                                         132.000000
# mean                                           42.530303
# std                                            20.157059
# min                                             1.000000
# 25%                                            26.675000
# 50%                                            42.900000
# 75%                                            56.325000
# max                                            95.500000
#
#        Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# count                                         122.000000
# mean                                           30.201639
# std                                            18.903198
# min                                             0.500000
# 25%                                            17.275000
# 50%                                            29.300000
# 75%                                            42.625000
# max                                            76.900000
#
#        Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# count                                         106.000000
# mean                                           15.013958
# std                                            12.389166
# min                                             0.000000
# 25%                                             5.763285
# 50%                                            11.500000
# 75%                                            21.850000
# max                                            59.600000
#
#        People using safely managed drinking water services (% of population)  \
# count                                          99.000000
# mean                                           33.478990
# std                                            26.678321
# min                                             5.770000
# 25%                                             8.975000
# 50%                                            28.390000
# 75%                                            43.890000
# max                                            92.660000
#
#        People using safely managed drinking water services, rural (% of rural population)  \
# count                                          88.000000
# mean                                           12.470568
# std                                            10.078371
# min                                             0.930000
# 25%                                             4.185000
# 50%                                            10.675000
# 75%                                            16.887500
# max                                            39.930000
#
#        People using safely managed drinking water services, urban (% of urban population)  \
# count                                         176.000000
# mean                                           51.549545
# std                                            24.157416
# min                                            11.200000
# 25%                                            34.125000
# 50%                                            51.365000
# 75%                                            70.747500
# max                                            89.540000
#
#        People using safely managed sanitation services (% of population)  ...  \
# count                                         132.000000                  ...
# mean                                           28.768939                  ...
# std                                            18.631510                  ...
# min                                             6.370000                  ...
# 25%                                            16.532500                  ...
# 50%                                            25.410000                  ...
# 75%                                            35.725000                  ...
# max                                            78.120000                  ...
#
#        Urban population (% of total population)  \
# count                                588.000000
# mean                                  43.164116
# std                                   18.086118
# min                                    9.860000
# 25%                                   28.795000
# 50%                                   41.560000
# 75%                                   56.945000
# max                                   88.980000
#
#        Urban population growth (annual %)  \
# count                          588.000000
# mean                             3.523061
# std                              1.456244
# min                             -4.650000
# 25%                              2.512500
# 50%                              3.730000
# 75%                              4.450000
# max                              7.400000
#
#        People using at least basic drinking water services (% of population)  \
# count                                         588.000000
# mean                                           65.994915
# std                                            17.283361
# min                                            28.960000
# 25%                                            52.375000
# 50%                                            64.470000
# 75%                                            79.165000
# max                                            99.870000
#
#        People using at least basic drinking water services, rural (% of rural population)  \
# count                                         566.000000
# mean                                           51.449576
# std                                            18.927868
# min                                            17.050000
# 25%                                            37.075000
# 50%                                            50.435000
# 75%                                            62.245000
# max                                            99.830000
#
#        People using at least basic drinking water services, urban (% of urban population)  \
# count                                         566.000000
# mean                                           84.268498
# std                                             9.307285
# min                                            52.010000
# 25%                                            78.080000
# 50%                                            85.420000
# 75%                                            90.082500
# max                                            99.920000
#
#        People using at least basic sanitation services (% of population)  \
# count                                         588.000000
# mean                                           39.469796
# std                                            26.304934
# min                                             4.990000
# 25%                                            18.197500
# 50%                                            32.555000
# 75%                                            54.810000
# max                                           100.000000
#
#        People using at least basic sanitation services, rural (% of rural population)  \
# count                                         566.000000
# mean                                           28.077208
# std                                            24.046725
# min                                             1.890000
# 25%                                             8.842500
# 50%                                            18.815000
# 75%                                            38.082500
# max                                            95.180000
#
#        People using at least basic sanitation services, urban  (% of urban population)  \
# count                                         566.000000
# mean                                           48.088375
# std                                            21.802128
# min                                            12.580000
# 25%                                            30.775000
# 50%                                            44.695000
# 75%                                            58.845000
# max                                            98.300000
#
#          latitude   longitude
# count  594.000000  594.000000
# mean     2.828796   17.342546
# std     15.678226   20.041257
# min    -30.559482  -24.013197
# 25%     -6.369028    0.824782
# 50%      6.744051   18.611308
# 75%     12.862807   31.465866
# max     33.886917   57.552152
#
# [8 rows x 24 columns]

# %% [markdown]
# #### 4.2. Analyses statistiques pour identifier les tendances des maladies, les facteurs de risque

# %% [markdown]
# #### * Tendances annuelles des cas de paludisme, classées par année du nombre de cas le plus élevé de paludisme au nombre de cas le plus faible

# %%
som_tendances_annuelles = dfc.groupby("Year")["Malaria cases reported"].sum().sort_values(ascending=False)

# %%
som_tendances_annuelles
# Out:
# Year
# 2017    128146255
# 2016    123330818
# 2015     92968526
# 2014     77028814
# 2013     47174959
# 2012     39719221
# 2011     23002865
# 2010     22184760
# 2009     14414616
# 2007     10102341
# 2008      9508374
# Name: Malaria cases reported, dtype: Int64

# %%
moy_tendances_annuelles = dfc.groupby("Year")["Malaria cases reported"].mean().sort_values(ascending=False)

# %%
moy_tendances_annuelles
# Out:
# Year
# 2017     2562925.1
# 2016    2466616.36
# 2015    1859370.52
# 2014    1540576.28
# 2013     943499.18
# 2012     794384.42
# 2011      460057.3
# 2010      443695.2
# 2009     288292.32
# 2007     202046.82
# 2008     190167.48
# Name: Malaria cases reported, dtype: Float64

# %% [markdown]
# #### * Tendances par pays des cas de paludisme de 2007-2017, classé par pays ayant le nombre de cas de paludisme le plus élevé au nombre de cas le plus faible

# %%
som_tendances_pays = dfc.groupby("Country Name")["Malaria cases reported"].sum().sort_values(ascending=False)

# %%
som_tendances_pays
# Out:
# Country Name
# Congo, Dem. Rep.            77555524
# Mozambique                  43984158
# Burkina Faso                41601963
# Uganda                      41126230
# Burundi                     40249714
# Nigeria                     40066570
# Ghana                       28008309
# Tanzania                    24283088
# Angola                      24034182
# Malawi                      19445640
# Niger                       18866709
# Zambia                      18619166
# Cote d'Ivoire               17978339
# Rwanda                      17498217
# Kenya                       17353851
# Ethiopia                    16266669
# Liberia                     12237026
# Mali                        12106257
# Sierra Leone                11919725
# Togo                        11162390
# Benin                        8579720
# Sudan                        7265570
# Chad                         6198112
# Madagascar                   4616832
# Guinea                       4580444
# Cameroon                     4373628
# Zimbabwe                     3344410
# Senegal                      3283980
# South Sudan                  3143581
# Central African Republic     2561261
# Gambia, The                  1675997
# Congo, Rep.                   932292
# Guinea-Bissau                 749386
# Equatorial Guinea             336825
# Eritrea                       306876
# Comoros                       289016
# Gabon                         264144
# Somalia                       254342
# Namibia                       120908
# Mauritania                    117335
# South Africa                   93089
# Djibouti                       61718
# Sao Tome and Principe          54276
# Botswana                        8756
# Eswatini                        4531
# Cabo Verde                       699
# Algeria                           94
# Seychelles                         0
# Libya                              0
# Egypt, Arab Rep.                   0
# Tunisia                            0
# Morocco                            0
# Mauritius                          0
# Lesotho                            0
# Name: Malaria cases reported, dtype: Int64

# %%
moy_tendances_pays = dfc.groupby("Country Name")["Malaria cases reported"].mean().sort_values(ascending=False)

# %%
moy_tendances_pays
# Out:
# Country Name
# Congo, Dem. Rep.            7050502.181818
# Mozambique                  3998559.818182
# Burkina Faso                3781996.636364
# Uganda                      3738748.181818
# Burundi                     3659064.909091
# Nigeria                     3642415.454545
# Ghana                       2546209.909091
# Tanzania                    2207553.454545
# Angola                      2184925.636364
# Malawi                      1767785.454545
# Niger                       1715155.363636
# Zambia                      1692651.454545
# Cote d'Ivoire               1634394.454545
# Rwanda                           1590747.0
# Kenya                       1577622.818182
# Ethiopia                    1478788.090909
# Liberia                     1112456.909091
# Mali                        1100568.818182
# Sierra Leone                1083611.363636
# Togo                        1014762.727273
# Benin                        779974.545455
# Sudan                        660506.363636
# Chad                         563464.727273
# Madagascar                        419712.0
# Guinea                            416404.0
# Cameroon                     397602.545455
# Zimbabwe                     304037.272727
# Senegal                      298543.636364
# South Sudan                  285780.090909
# Central African Republic     232841.909091
# Gambia, The                  152363.363636
# Congo, Rep.                   84753.818182
# Guinea-Bissau                      68126.0
# Equatorial Guinea             30620.454545
# Eritrea                       27897.818182
# Comoros                       26274.181818
# Gabon                         24013.090909
# Somalia                            23122.0
# Namibia                       10991.636364
# Mauritania                    10666.818182
# South Africa                   8462.636364
# Djibouti                       5610.727273
# Sao Tome and Principe          4934.181818
# Botswana                             796.0
# Eswatini                        411.909091
# Cabo Verde                       63.545455
# Algeria                           8.545455
# Egypt, Arab Rep.                       0.0
# Morocco                                0.0
# Libya                                  0.0
# Lesotho                               <NA>
# Mauritius                             <NA>
# Seychelles                            <NA>
# Tunisia                               <NA>
# Name: Malaria cases reported, dtype: Float64

# %% [markdown]
# ##### * Visualisation des résultats des tendances annuelles

# %%
som_tendances_annuelles.plot(kind="line")
plt.xlabel("Year")
plt.ylabel("Malaria cases reported")
plt.title("Figure 01: Tendances annuelles des cas de paludisme en Afrique")
plt.show()

# %% [markdown]
# ### Lecture de la Figure 01 : la tendance est que le nombre de cas de paludisme en Afrique n'a fait qu'augmenter d'année en année entre 2007 et 2017

# %% [markdown]
# #### * Tendances des cas de paludisme en fonction de l'utilisation de moustiquaires imprégnées d'insecticide (% de la population de moins de 5 ans)

# %%
som_tendances_treated_bed_nets = dfc.groupby("Use of insecticide-treated bed nets (% of under-5 population)")["Malaria cases reported"].sum()

# %%
som_tendances_treated_bed_nets
# Out:
# Use of insecticide-treated bed nets (% of under-5 population)
# 1.0          84
# 1.5         268
# 4.5       33405
# 5.0       44518
# 5.6        4911
#          ...
# 75.3    5428655
# 76.5     224498
# 79.3    2454508
# 80.6      93431
# 95.5    2392108
# Name: Malaria cases reported, Length: 117, dtype: Int64

# %% [markdown]
# #### * Visualisation de la tendance des cas de paludisme en Afrique pour enfants de -5 ans dormant sous moustiquaires imprégnés

# %%
som_tendances_treated_bed_nets.plot(kind="line")
plt.xlabel("Use of insecticide-treated bed nets (% of under-5 population)")
plt.ylabel("Malaria cases reported")
plt.title("Figure 02 : Tendances des cas de paludisme en Afrique pour enfants de -5 ans dormant sous moustiquaires imprégnés")
plt.show()

# %% [markdown]
# ### Lecture de la Figure 02 : la tendance est que plus les enfants de moins de 5 ans dorment sous moustiquaires imprégnés, moins ils ont le paludisme.

# %% [markdown]
# #### 4.3. Corrélations entre les variables pour analyser les relations entre les facteurs de risque et les cas de paludisme

# %% [markdown]
# ##### Definition : La relation statistique entre deux variables est appelée leur corrélation.

# %%
correlation_matrix = dfc.corr()
# Out:
# C:\Users\HP ZBOOK\AppData\Local\Temp\ipykernel_28904\2508308341.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dfc.corr()

# %%
correlation_matrix
# Out:
#                                                             Year  \
# Year                                                1.000000e+00
# Incidence of malaria (per 1,000 population at r... -7.060502e-02
# Malaria cases reported                              3.713634e-01
# Use of insecticide-treated bed nets (% of under...  5.310142e-01
# % of children under age 5 with fever receiving ... -4.381980e-02
# % of pregnant women using Intermittent preventi...  4.544615e-01
# % of population using safely managed drinking w...  8.946214e-02
# % of rural population using safely managed drin...  1.711018e-01
# % of urban population using safely managed drin...  5.008197e-02
# % of population using safely managed sanitation...  8.140907e-02
# % of rural population using safely managed sani...  2.196390e-01
# % of urban population using safely managed sani...  5.671254e-02
# Rural population (% of total population)           -8.429034e-02
# Rural population growth (annual %)                 -4.988517e-02
# Urban population (% of total population)            8.429226e-02
# Urban population growth (annual %)                 -5.670150e-02
# % of population using at least basic drinking w...  1.194164e-01
# % of rural population using at least basic drin...  1.138409e-01
# % of urban population using at least basic drin...  1.034695e-01
#  % of population using at least basic sanitatio...  6.887078e-02
# % of rural population using at least basic sani...  7.023027e-02
# % of urban population using at least basic sani...  6.026910e-02
# latitude                                           -1.513567e-15
# longitude                                          -1.679748e-15
#
#                                                     Incidence of malaria (per 1,000 population at risk)  \
# Year                                                                                        -0.070605
# Incidence of malaria (per 1,000 population at r...                                           1.000000
# Malaria cases reported                                                                       0.288509
# Use of insecticide-treated bed nets (% of under...                                           0.009608
# % of children under age 5 with fever receiving ...                                           0.532327
# % of pregnant women using Intermittent preventi...                                           0.154911
# % of population using safely managed drinking w...                                          -0.501461
# % of rural population using safely managed drin...                                          -0.459303
# % of urban population using safely managed drin...                                          -0.678977
# % of population using safely managed sanitation...                                          -0.613592
# % of rural population using safely managed sani...                                          -0.205144
# % of urban population using safely managed sani...                                          -0.499475
# Rural population (% of total population)                                                     0.253799
# Rural population growth (annual %)                                                           0.411329
# Urban population (% of total population)                                                    -0.253803
# Urban population growth (annual %)                                                           0.350415
# % of population using at least basic drinking w...                                          -0.410028
# % of rural population using at least basic drin...                                          -0.352018
# % of urban population using at least basic drin...                                          -0.430043
#  % of population using at least basic sanitatio...                                          -0.512391
# % of rural population using at least basic sani...                                          -0.431779
# % of urban population using at least basic sani...                                          -0.479482
# latitude                                                                                     0.065572
# longitude                                                                                   -0.287883
#
#                                                     Malaria cases reported  \
# Year                                                              0.371363
# Incidence of malaria (per 1,000 population at r...                0.288509
# Malaria cases reported                                            1.000000
# Use of insecticide-treated bed nets (% of under...                0.271116
# % of children under age 5 with fever receiving ...                0.301719
# % of pregnant women using Intermittent preventi...                0.238335
# % of population using safely managed drinking w...               -0.278893
# % of rural population using safely managed drin...               -0.197603
# % of urban population using safely managed drin...               -0.408585
# % of population using safely managed sanitation...               -0.172106
# % of rural population using safely managed sani...                0.103046
# % of urban population using safely managed sani...               -0.106211
# Rural population (% of total population)                          0.219674
# Rural population growth (annual %)                                0.254232
# Urban population (% of total population)                         -0.219683
# Urban population growth (annual %)                                0.284905
# % of population using at least basic drinking w...               -0.257250
# % of rural population using at least basic drin...               -0.199931
# % of urban population using at least basic drin...               -0.177815
#  % of population using at least basic sanitatio...               -0.202425
# % of rural population using at least basic sani...               -0.128802
# % of urban population using at least basic sani...               -0.231405
# latitude                                                         -0.096510
# longitude                                                         0.072659
#
#                                                     Use of insecticide-treated bed nets (% of under-5 population)  \
# Year                                                                                         0.531014
# Incidence of malaria (per 1,000 population at r...                                           0.009608
# Malaria cases reported                                                                       0.271116
# Use of insecticide-treated bed nets (% of under...                                           1.000000
# % of children under age 5 with fever receiving ...                                           0.079162
# % of pregnant women using Intermittent preventi...                                           0.307991
# % of population using safely managed drinking w...                                           0.051592
# % of rural population using safely managed drin...                                          -0.099520
# % of urban population using safely managed drin...                                          -0.121495
# % of population using safely managed sanitation...                                          -0.293166
# % of rural population using safely managed sani...                                           0.038775
# % of urban population using safely managed sani...                                          -0.198089
# Rural population (% of total population)                                                     0.136593
# Rural population growth (annual %)                                                           0.198001
# Urban population (% of total population)                                                    -0.136613
# Urban population growth (annual %)                                                           0.214265
# % of population using at least basic drinking w...                                           0.034067
# % of rural population using at least basic drin...                                           0.146298
# % of urban population using at least basic drin...                                           0.004874
#  % of population using at least basic sanitatio...                                          -0.042730
# % of rural population using at least basic sani...                                           0.057677
# % of urban population using at least basic sani...                                          -0.150451
# latitude                                                                                     0.163616
# longitude                                                                                   -0.011117
#
#                                                     % of children under age 5 with fever receiving antimalarial drugs  \
# Year                                                                                        -0.043820
# Incidence of malaria (per 1,000 population at r...                                           0.532327
# Malaria cases reported                                                                       0.301719
# Use of insecticide-treated bed nets (% of under...                                           0.079162
# % of children under age 5 with fever receiving ...                                           1.000000
# % of pregnant women using Intermittent preventi...                                           0.314459
# % of population using safely managed drinking w...                                          -0.208050
# % of rural population using safely managed drin...                                          -0.156504
# % of urban population using safely managed drin...                                          -0.616924
# % of population using safely managed sanitation...                                          -0.153175
# % of rural population using safely managed sani...                                           0.042544
# % of urban population using safely managed sani...                                           0.218336
# Rural population (% of total population)                                                     0.090178
# Rural population growth (annual %)                                                           0.289761
# Urban population (% of total population)                                                    -0.090201
# Urban population growth (annual %)                                                           0.363973
# % of population using at least basic drinking w...                                          -0.207770
# % of rural population using at least basic drin...                                          -0.154126
# % of urban population using at least basic drin...                                          -0.394741
#  % of population using at least basic sanitatio...                                          -0.461137
# % of rural population using at least basic sani...                                          -0.396981
# % of urban population using at least basic sani...                                          -0.463726
# latitude                                                                                     0.153533
# longitude                                                                                   -0.110809
#
#                                                     % of pregnant women using Intermittent preventive treatment (IPT) of malaria in pregnancy  \
# Year                                                                                         0.454461
# Incidence of malaria (per 1,000 population at r...                                           0.154911
# Malaria cases reported                                                                       0.238335
# Use of insecticide-treated bed nets (% of under...                                           0.307991
# % of children under age 5 with fever receiving ...                                           0.314459
# % of pregnant women using Intermittent preventi...                                           1.000000
# % of population using safely managed drinking w...                                           0.184018
# % of rural population using safely managed drin...                                          -0.272432
# % of urban population using safely managed drin...                                           0.123014
# % of population using safely managed sanitation...                                          -0.201184
# % of rural population using safely managed sani...                                          -0.231655
# % of urban population using safely managed sani...                                          -0.112146
# Rural population (% of total population)                                                    -0.178830
# Rural population growth (annual %)                                                          -0.043661
# Urban population (% of total population)                                                     0.178811
# Urban population growth (annual %)                                                          -0.012669
# % of population using at least basic drinking w...                                           0.241572
# % of rural population using at least basic drin...                                           0.186519
# % of urban population using at least basic drin...                                           0.140941
#  % of population using at least basic sanitatio...                                          -0.190158
# % of rural population using at least basic sani...                                          -0.224373
# % of urban population using at least basic sani...                                          -0.172149
# latitude                                                                                     0.098717
# longitude                                                                                   -0.203676
#
#                                                     % of population using safely managed drinking water services  \
# Year                                                                                         0.089462
# Incidence of malaria (per 1,000 population at r...                                          -0.501461
# Malaria cases reported                                                                      -0.278893
# Use of insecticide-treated bed nets (% of under...                                           0.051592
# % of children under age 5 with fever receiving ...                                          -0.208050
# % of pregnant women using Intermittent preventi...                                           0.184018
# % of population using safely managed drinking w...                                           1.000000
# % of rural population using safely managed drin...                                           0.921974
# % of urban population using safely managed drin...                                           0.946457
# % of population using safely managed sanitation...                                           0.927503
# % of rural population using safely managed sani...                                           0.950821
# % of urban population using safely managed sani...                                           0.898606
# Rural population (% of total population)                                                    -0.822383
# Rural population growth (annual %)                                                          -0.826812
# Urban population (% of total population)                                                     0.822392
# Urban population growth (annual %)                                                          -0.856482
# % of population using at least basic drinking w...                                           0.870408
# % of rural population using at least basic drin...                                           0.774201
# % of urban population using at least basic drin...                                           0.936218
#  % of population using at least basic sanitatio...                                           0.886794
# % of rural population using at least basic sani...                                           0.837097
# % of urban population using at least basic sani...                                           0.873025
# latitude                                                                                     0.809231
# longitude                                                                                   -0.321583
#
#                                                     % of rural population using safely managed drinking water services  \
# Year                                                                                         0.171102
# Incidence of malaria (per 1,000 population at r...                                          -0.459303
# Malaria cases reported                                                                      -0.197603
# Use of insecticide-treated bed nets (% of under...                                          -0.099520
# % of children under age 5 with fever receiving ...                                          -0.156504
# % of pregnant women using Intermittent preventi...                                          -0.272432
# % of population using safely managed drinking w...                                           0.921974
# % of rural population using safely managed drin...                                           1.000000
# % of urban population using safely managed drin...                                           0.814306
# % of population using safely managed sanitation...                                           0.951713
# % of rural population using safely managed sani...                                           0.978063
# % of urban population using safely managed sani...                                           0.977609
# Rural population (% of total population)                                                    -0.695418
# Rural population growth (annual %)                                                          -0.826590
# Urban population (% of total population)                                                     0.695415
# Urban population growth (annual %)                                                          -0.723214
# % of population using at least basic drinking w...                                           0.754185
# % of rural population using at least basic drin...                                           0.592671
# % of urban population using at least basic drin...                                           0.821300
#  % of population using at least basic sanitatio...                                           0.932769
# % of rural population using at least basic sani...                                           0.867757
# % of urban population using at least basic sani...                                           0.925027
# latitude                                                                                     0.761962
# longitude                                                                                   -0.520107
#
#                                                     % of urban population using safely managed drinking water services  \
# Year                                                                                         0.050082
# Incidence of malaria (per 1,000 population at r...                                          -0.678977
# Malaria cases reported                                                                      -0.408585
# Use of insecticide-treated bed nets (% of under...                                          -0.121495
# % of children under age 5 with fever receiving ...                                          -0.616924
# % of pregnant women using Intermittent preventi...                                           0.123014
# % of population using safely managed drinking w...                                           0.946457
# % of rural population using safely managed drin...                                           0.814306
# % of urban population using safely managed drin...                                           1.000000
# % of population using safely managed sanitation...                                           0.904425
# % of rural population using safely managed sani...                                          -0.046646
# % of urban population using safely managed sani...                                           0.947106
# Rural population (% of total population)                                                    -0.507889
# Rural population growth (annual %)                                                          -0.729787
# Urban population (% of total population)                                                     0.507907
# Urban population growth (annual %)                                                          -0.654459
# % of population using at least basic drinking w...                                           0.735460
# % of rural population using at least basic drin...                                           0.661666
# % of urban population using at least basic drin...                                           0.942218
#  % of population using at least basic sanitatio...                                           0.742667
# % of rural population using at least basic sani...                                           0.656613
# % of urban population using at least basic sani...                                           0.749673
# latitude                                                                                    -0.309760
# longitude                                                                                   -0.050205
#
#                                                     % of population using safely managed sanitation services  \
# Year                                                                                         0.081409
# Incidence of malaria (per 1,000 population at r...                                          -0.613592
# Malaria cases reported                                                                      -0.172106
# Use of insecticide-treated bed nets (% of under...                                          -0.293166
# % of children under age 5 with fever receiving ...                                          -0.153175
# % of pregnant women using Intermittent preventi...                                          -0.201184
# % of population using safely managed drinking w...                                           0.927503
# % of rural population using safely managed drin...                                           0.951713
# % of urban population using safely managed drin...                                           0.904425
# % of population using safely managed sanitation...                                           1.000000
# % of rural population using safely managed sani...                                           0.650613
# % of urban population using safely managed sani...                                           0.971281
# Rural population (% of total population)                                                    -0.427094
# Rural population growth (annual %)                                                          -0.368766
# Urban population (% of total population)                                                     0.427114
# Urban population growth (annual %)                                                          -0.618049
# % of population using at least basic drinking w...                                           0.666937
# % of rural population using at least basic drin...                                           0.649492
# % of urban population using at least basic drin...                                           0.656757
#  % of population using at least basic sanitatio...                                           0.677943
# % of rural population using at least basic sani...                                           0.703158
# % of urban population using at least basic sani...                                           0.736721
# latitude                                                                                     0.555364
# longitude                                                                                    0.317706
#
#                                                     ...  \
# Year                                                ...
# Incidence of malaria (per 1,000 population at r...  ...
# Malaria cases reported                              ...
# Use of insecticide-treated bed nets (% of under...  ...
# % of children under age 5 with fever receiving ...  ...
# % of pregnant women using Intermittent preventi...  ...
# % of population using safely managed drinking w...  ...
# % of rural population using safely managed drin...  ...
# % of urban population using safely managed drin...  ...
# % of population using safely managed sanitation...  ...
# % of rural population using safely managed sani...  ...
# % of urban population using safely managed sani...  ...
# Rural population (% of total population)            ...
# Rural population growth (annual %)                  ...
# Urban population (% of total population)            ...
# Urban population growth (annual %)                  ...
# % of population using at least basic drinking w...  ...
# % of rural population using at least basic drin...  ...
# % of urban population using at least basic drin...  ...
#  % of population using at least basic sanitatio...  ...
# % of rural population using at least basic sani...  ...
# % of urban population using at least basic sani...  ...
# latitude                                            ...
# longitude                                           ...
#
#                                                     Urban population (% of total population)  \
# Year                                                                                0.084292
# Incidence of malaria (per 1,000 population at r...                                 -0.253803
# Malaria cases reported                                                             -0.219683
# Use of insecticide-treated bed nets (% of under...                                 -0.136613
# % of children under age 5 with fever receiving ...                                 -0.090201
# % of pregnant women using Intermittent preventi...                                  0.178811
# % of population using safely managed drinking w...                                  0.822392
# % of rural population using safely managed drin...                                  0.695415
# % of urban population using safely managed drin...                                  0.507907
# % of population using safely managed sanitation...                                  0.427114
# % of rural population using safely managed sani...                                  0.588600
# % of urban population using safely managed sani...                                  0.406288
# Rural population (% of total population)                                           -1.000000
# Rural population growth (annual %)                                                 -0.651653
# Urban population (% of total population)                                            1.000000
# Urban population growth (annual %)                                                 -0.228287
# % of population using at least basic drinking w...                                  0.631472
# % of rural population using at least basic drin...                                  0.290278
# % of urban population using at least basic drin...                                  0.280251
#  % of population using at least basic sanitatio...                                  0.518670
# % of rural population using at least basic sani...                                  0.281079
# % of urban population using at least basic sani...                                  0.465425
# latitude                                                                            0.227344
# longitude                                                                          -0.305732
#
#                                                     Urban population growth (annual %)  \
# Year                                                                         -0.056701
# Incidence of malaria (per 1,000 population at r...                            0.350415
# Malaria cases reported                                                        0.284905
# Use of insecticide-treated bed nets (% of under...                            0.214265
# % of children under age 5 with fever receiving ...                            0.363973
# % of pregnant women using Intermittent preventi...                           -0.012669
# % of population using safely managed drinking w...                           -0.856482
# % of rural population using safely managed drin...                           -0.723214
# % of urban population using safely managed drin...                           -0.654459
# % of population using safely managed sanitation...                           -0.618049
# % of rural population using safely managed sani...                           -0.033198
# % of urban population using safely managed sani...                           -0.531640
# Rural population (% of total population)                                      0.228283
# Rural population growth (annual %)                                            0.329666
# Urban population (% of total population)                                     -0.228287
# Urban population growth (annual %)                                            1.000000
# % of population using at least basic drinking w...                           -0.532294
# % of rural population using at least basic drin...                           -0.524479
# % of urban population using at least basic drin...                           -0.410877
#  % of population using at least basic sanitatio...                           -0.525262
# % of rural population using at least basic sani...                           -0.454676
# % of urban population using at least basic sani...                           -0.470031
# latitude                                                                      0.023965
# longitude                                                                    -0.146540
#
#                                                     % of population using at least basic drinking water services  \
# Year                                                                                         0.119416
# Incidence of malaria (per 1,000 population at r...                                          -0.410028
# Malaria cases reported                                                                      -0.257250
# Use of insecticide-treated bed nets (% of under...                                           0.034067
# % of children under age 5 with fever receiving ...                                          -0.207770
# % of pregnant women using Intermittent preventi...                                           0.241572
# % of population using safely managed drinking w...                                           0.870408
# % of rural population using safely managed drin...                                           0.754185
# % of urban population using safely managed drin...                                           0.735460
# % of population using safely managed sanitation...                                           0.666937
# % of rural population using safely managed sani...                                           0.734516
# % of urban population using safely managed sani...                                           0.604833
# Rural population (% of total population)                                                    -0.631470
# Rural population growth (annual %)                                                          -0.606765
# Urban population (% of total population)                                                     0.631472
# Urban population growth (annual %)                                                          -0.532294
# % of population using at least basic drinking w...                                           1.000000
# % of rural population using at least basic drin...                                           0.916134
# % of urban population using at least basic drin...                                           0.799900
#  % of population using at least basic sanitatio...                                           0.778722
# % of rural population using at least basic sani...                                           0.693788
# % of urban population using at least basic sani...                                           0.680063
# latitude                                                                                     0.072473
# longitude                                                                                   -0.128139
#
#                                                     % of rural population using at least basic drinking water services  \
# Year                                                                                         0.113841
# Incidence of malaria (per 1,000 population at r...                                          -0.352018
# Malaria cases reported                                                                      -0.199931
# Use of insecticide-treated bed nets (% of under...                                           0.146298
# % of children under age 5 with fever receiving ...                                          -0.154126
# % of pregnant women using Intermittent preventi...                                           0.186519
# % of population using safely managed drinking w...                                           0.774201
# % of rural population using safely managed drin...                                           0.592671
# % of urban population using safely managed drin...                                           0.661666
# % of population using safely managed sanitation...                                           0.649492
# % of rural population using safely managed sani...                                           0.659321
# % of urban population using safely managed sani...                                           0.561416
# Rural population (% of total population)                                                    -0.290277
# Rural population growth (annual %)                                                          -0.433899
# Urban population (% of total population)                                                     0.290278
# Urban population growth (annual %)                                                          -0.524479
# % of population using at least basic drinking w...                                           0.916134
# % of rural population using at least basic drin...                                           1.000000
# % of urban population using at least basic drin...                                           0.748751
#  % of population using at least basic sanitatio...                                           0.682571
# % of rural population using at least basic sani...                                           0.705651
# % of urban population using at least basic sani...                                           0.612246
# latitude                                                                                     0.033603
# longitude                                                                                   -0.130554
#
#                                                     % of urban population using at least basic drinking water services  \
# Year                                                                                         0.103469
# Incidence of malaria (per 1,000 population at r...                                          -0.430043
# Malaria cases reported                                                                      -0.177815
# Use of insecticide-treated bed nets (% of under...                                           0.004874
# % of children under age 5 with fever receiving ...                                          -0.394741
# % of pregnant women using Intermittent preventi...                                           0.140941
# % of population using safely managed drinking w...                                           0.936218
# % of rural population using safely managed drin...                                           0.821300
# % of urban population using safely managed drin...                                           0.942218
# % of population using safely managed sanitation...                                           0.656757
# % of rural population using safely managed sani...                                           0.518164
# % of urban population using safely managed sani...                                           0.523233
# Rural population (% of total population)                                                    -0.280246
# Rural population growth (annual %)                                                          -0.424954
# Urban population (% of total population)                                                     0.280251
# Urban population growth (annual %)                                                          -0.410877
# % of population using at least basic drinking w...                                           0.799900
# % of rural population using at least basic drin...                                           0.748751
# % of urban population using at least basic drin...                                           1.000000
#  % of population using at least basic sanitatio...                                           0.603258
# % of rural population using at least basic sani...                                           0.616268
# % of urban population using at least basic sani...                                           0.534772
# latitude                                                                                    -0.068615
# longitude                                                                                   -0.066249
#
#                                                      % of population using at least basic sanitation services  \
# Year                                                                                         0.068871
# Incidence of malaria (per 1,000 population at r...                                          -0.512391
# Malaria cases reported                                                                      -0.202425
# Use of insecticide-treated bed nets (% of under...                                          -0.042730
# % of children under age 5 with fever receiving ...                                          -0.461137
# % of pregnant women using Intermittent preventi...                                          -0.190158
# % of population using safely managed drinking w...                                           0.886794
# % of rural population using safely managed drin...                                           0.932769
# % of urban population using safely managed drin...                                           0.742667
# % of population using safely managed sanitation...                                           0.677943
# % of rural population using safely managed sani...                                           0.685950
# % of urban population using safely managed sani...                                           0.664733
# Rural population (% of total population)                                                    -0.518668
# Rural population growth (annual %)                                                          -0.528266
# Urban population (% of total population)                                                     0.518670
# Urban population growth (annual %)                                                          -0.525262
# % of population using at least basic drinking w...                                           0.778722
# % of rural population using at least basic drin...                                           0.682571
# % of urban population using at least basic drin...                                           0.603258
#  % of population using at least basic sanitatio...                                           1.000000
# % of rural population using at least basic sani...                                           0.948994
# % of urban population using at least basic sani...                                           0.946098
# latitude                                                                                     0.105754
# longitude                                                                                    0.114494
#
#                                                     % of rural population using at least basic sanitation services  \
# Year                                                                                         0.070230
# Incidence of malaria (per 1,000 population at r...                                          -0.431779
# Malaria cases reported                                                                      -0.128802
# Use of insecticide-treated bed nets (% of under...                                           0.057677
# % of children under age 5 with fever receiving ...                                          -0.396981
# % of pregnant women using Intermittent preventi...                                          -0.224373
# % of population using safely managed drinking w...                                           0.837097
# % of rural population using safely managed drin...                                           0.867757
# % of urban population using safely managed drin...                                           0.656613
# % of population using safely managed sanitation...                                           0.703158
# % of rural population using safely managed sani...                                           0.661972
# % of urban population using safely managed sani...                                           0.616705
# Rural population (% of total population)                                                    -0.281076
# Rural population growth (annual %)                                                          -0.407762
# Urban population (% of total population)                                                     0.281079
# Urban population growth (annual %)                                                          -0.454676
# % of population using at least basic drinking w...                                           0.693788
# % of rural population using at least basic drin...                                           0.705651
# % of urban population using at least basic drin...                                           0.616268
#  % of population using at least basic sanitatio...                                           0.948994
# % of rural population using at least basic sani...                                           1.000000
# % of urban population using at least basic sani...                                           0.837238
# latitude                                                                                     0.010485
# longitude                                                                                    0.093684
#
#                                                     % of urban population using at least basic sanitation services  \
# Year                                                                                         0.060269
# Incidence of malaria (per 1,000 population at r...                                          -0.479482
# Malaria cases reported                                                                      -0.231405
# Use of insecticide-treated bed nets (% of under...                                          -0.150451
# % of children under age 5 with fever receiving ...                                          -0.463726
# % of pregnant women using Intermittent preventi...                                          -0.172149
# % of population using safely managed drinking w...                                           0.873025
# % of rural population using safely managed drin...                                           0.925027
# % of urban population using safely managed drin...                                           0.749673
# % of population using safely managed sanitation...                                           0.736721
# % of rural population using safely managed sani...                                           0.617195
# % of urban population using safely managed sani...                                           0.654656
# Rural population (% of total population)                                                    -0.465422
# Rural population growth (annual %)                                                          -0.471753
# Urban population (% of total population)                                                     0.465425
# Urban population growth (annual %)                                                          -0.470031
# % of population using at least basic drinking w...                                           0.680063
# % of rural population using at least basic drin...                                           0.612246
# % of urban population using at least basic drin...                                           0.534772
#  % of population using at least basic sanitatio...                                           0.946098
# % of rural population using at least basic sani...                                           0.837238
# % of urban population using at least basic sani...                                           1.000000
# latitude                                                                                     0.147165
# longitude                                                                                   -0.008999
#
#                                                         latitude     longitude
# Year                                               -1.513567e-15 -1.679748e-15
# Incidence of malaria (per 1,000 population at r...  6.557173e-02 -2.878833e-01
# Malaria cases reported                             -9.650952e-02  7.265935e-02
# Use of insecticide-treated bed nets (% of under...  1.636158e-01 -1.111728e-02
# % of children under age 5 with fever receiving ...  1.535330e-01 -1.108090e-01
# % of pregnant women using Intermittent preventi...  9.871689e-02 -2.036763e-01
# % of population using safely managed drinking w...  8.092313e-01 -3.215831e-01
# % of rural population using safely managed drin...  7.619622e-01 -5.201074e-01
# % of urban population using safely managed drin... -3.097595e-01 -5.020529e-02
# % of population using safely managed sanitation...  5.553642e-01  3.177056e-01
# % of rural population using safely managed sani...  1.682966e-01 -2.408546e-01
# % of urban population using safely managed sani...  4.990662e-01  3.029556e-01
# Rural population (% of total population)           -2.273449e-01  3.057347e-01
# Rural population growth (annual %)                  1.005307e-01  9.706958e-02
# Urban population (% of total population)            2.273442e-01 -3.057322e-01
# Urban population growth (annual %)                  2.396536e-02 -1.465401e-01
# % of population using at least basic drinking w...  7.247320e-02 -1.281392e-01
# % of rural population using at least basic drin...  3.360347e-02 -1.305536e-01
# % of urban population using at least basic drin... -6.861537e-02 -6.624921e-02
#  % of population using at least basic sanitatio...  1.057538e-01  1.144943e-01
# % of rural population using at least basic sani...  1.048535e-02  9.368387e-02
# % of urban population using at least basic sani...  1.471646e-01 -8.998636e-03
# latitude                                            1.000000e+00 -5.050025e-01
# longitude                                          -5.050025e-01  1.000000e+00
#
# [24 rows x 24 columns]

# %% [markdown]
# #### Analyse des corrélations et identification des facteurs de risque potentiels en examinant les valeurs de corrélation

# %% [markdown]
# ##### * Corrélations entre les cas de paludisme et les variables démographiques

# %% [markdown]
# ###### - Avec Incidence du paludisme (pour 1 000 habitants à risque)

# %%
corr_cases_population_1 = correlation_matrix["Malaria cases reported"]["Incidence of malaria (per 1,000 population at risk)"]

# %%
corr_cases_population_1
# Out:
# 0.28850886831479716

# %% [markdown]
# ##### - Avec % d'enfants de moins de 5 ans ayant de la fièvre recevant des médicaments antipaludiques

# %%
corr_cases_population_2 = correlation_matrix["Malaria cases reported"]["% of children under age 5 with fever receiving antimalarial drugs"]

# %%
corr_cases_population_2
# Out:
# 0.30171947845151337

# %% [markdown]
# ###### - Avec l'utilisation de moustiquaires imprégnées d'insecticide (% de la population de moins de 5 ans)

# %%
corr_cases_population_3 = correlation_matrix["Malaria cases reported"]["Use of insecticide-treated bed nets (% of under-5 population)"]

# %%
corr_cases_population_3
# Out:
# 0.2711160562803437

# %% [markdown]
# ###### - Avec la Population urbaine (% de la population totale)

# %%
corr_cases_population_4 = correlation_matrix["Malaria cases reported"]["Urban population growth (annual %)"]

# %%
corr_cases_population_4
# Out:
# 0.28490501349417036

# %% [markdown]
# ##### Forte Corrélation entre "% of rural population using safely managed sanitation services" et "% of rural population using safely managed drinking water services"

# %%
corr_cases_population_5 = correlation_matrix["% of rural population using safely managed sanitation services"]["% of rural population using safely managed drinking water services"]

# %%
corr_cases_population_5
# Out:
# 0.9780628308867829

# %% [markdown]
# #### Machine Learning : Modélisation des données pour identifier des modèles et des relations importantes dans les données

# %%
## Utilisons la bibliothèque scikit-learn pour effectuer une régression linéaire et importons le modèle de régression linéaire
from sklearn.linear_model import LinearRegression
## Le module Impute de Sklearn (scikit-learn) permet de nettoyer notre dataset des valeurs manquantes qui le composes.
## SimpleImputer remplace toute valeur manquante par une statistique ou une constante donnée
from sklearn.impute import SimpleImputer

# %%
## X représente des variables indépendantes : dans notre cas "% d'enfants de moins de 5 ans dormant sous moustiquaires imprégnées" et "% de femmes enceintes utilisant le traitement préventif intermittent (TPI) du paludisme pendant la grossesse"
X = dfc[["Use of insecticide-treated bed nets (% of under-5 population)", "% of pregnant women using Intermittent preventive treatment (IPT) of malaria in pregnancy"]]
## y représente la variable cible : dans notre cas "Year (Année)"
y = dfc["Year"]

# %%
## Utilisons SimpleImputer pour remplacer toute valeur manquante par une statistique ou une constante donnée. Dans notre cas, la moyenne des valeurs non manquantes
imputer = SimpleImputer(strategy='mean', missing_values=np.nan)
## Transformons dans les variables indépendantes contenues dans X, les valeurs manquantes par np.nan
X_imputed = imputer.fit_transform(X)

# %%
## Utilisons SimpleImputer pour remplacer toute valeur manquante par une statistique ou une constante donnée. Dans notre cas, la moyenne des valeurs non manquantes
imputer_y = SimpleImputer(strategy='mean')
## Appelons la méthode `reshape` sur `y.values`, pour remodeler le tableau en un tableau 2D avec une seule colonne, 
## ce qui est le format d'entrée attendu pour la méthode `fit_transform` de la classe `SimpleImputer`.
y_imputed = imputer_y.fit_transform(y.values.reshape(-1, 1))

# %%
## Instancions ensuite un objet modèle de régression linéaire en utilisant la classe LinearRegression().
model = LinearRegression()
## À l'aide de la méthode fit(), entraînons le modèle en utilisant les données X et y.
model.fit(X_imputed, y_imputed)
## Utilisons la méthode predict() pour effectuer des prédictions sur les données d'entraînement X et stockez les prédictions 
## résultantes dans la variable predictions.
predictions = model.predict(X_imputed)

# %% [markdown]
# #### Machine Learning : Evaluation du modèle de Regression Linéaire

# %%
## Importation de la fonction "mean_squared_error" du module "sklearn.metrics". Cela permettra de calculer l'erreur 
## quadratique moyenne ou Mean Squared Error(MSE).
from sklearn.metrics import mean_squared_error

## Calcul de l'erreur quadratique moyenne (MSE) entre les valeurs réelles 'y' et les valeurs prédites 'predictions' 
## en utilisant la fonction 'mean_squared_error'.
mse = mean_squared_error(y, predictions)

## Calcul de la racine carrée de l'erreur quadratique moyenne (MSE) en utilisant la fonction `np.sqrt` de numpy.
rmse = np.sqrt(mse)

## Affichage de la valeur du RMSE en utilisant la fonction 'print'
## Habituellement, un score RMSE inférieur à 180 est considéré comme un bon score pour un algorithme qui fonctionne modérément 
## ou bien. Dans le cas où la valeur RMSE dépasse 180, nous devons effectuer une sélection de caractéristiques et un réglage 
## des paramètres hyper sur les paramètres du modèle.
print("RMSE:", rmse)
# Out:
# RMSE: 3.0520908649792458

# %% [markdown]
# #### Conclusion RMSE : Le résultat du RMSE est inférieur à 180, donc notre algorithme de Machine Learning fonctionne bien

# %% [markdown]
# #### Machine Learning : Communication des résultats

# %% [markdown]
# #### Visualisation des résultats

# %%
plt.scatter(X['Use of insecticide-treated bed nets (% of under-5 population)'], y)
plt.plot(X['Use of insecticide-treated bed nets (% of under-5 population)'], predictions, color='red')
plt.xlabel('Use of insecticide-treated bed nets (% of under-5 population)')
plt.ylabel('Year')
plt.title("Figure 03 : Visualisation des résultats de notre modèle de Regression Linéaire")
plt.show()

# %% [markdown]
# ### Lecture de la Figure 03 : le taux d'enfants de moins de 5 ans dormant sous moustiquaires imprégnés, continuera à augmenter d'année en année afin de réduire le nombre de cas de paludisme.
